# %%
import tensorflow as tf
import PIL
from PIL import Image
import pandas as pd

"""
Pillow is a powerful Python Imaging Library (PIL) fork that provides easy-to-use methods foropening, manipulating, and
saving image files in various formats.
"""
# Out:
# '\nPillow is a powerful Python Imaging Library (PIL) fork that provides easy-to-use methods foropening, manipulating, and \nsaving image files in various formats.\n'

# %%
pic1 = Image.open('/content/Photo.jpg')
pic1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=390x510>

# %%
pic1.size
# width : 390 , height : 510 pixels
# Out:
# (390, 510)

# %%
pic1.mode
# Colorful mode
# Out:
# 'RGB'

# %%
# CONVERT THE IMAGE INTO ARRAY
from numpy import asarray
data = asarray(pic1)
data
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 82, 153, 241],
#         [ 11,  73, 158],
#         [ 22,  65, 144],
#         ...,
#         [ 20,  64, 159],
#         [ 23,  66, 158],
#         [ 50,  96, 184]],
#
#        [[ 98, 176, 255],
#         [  6,  73, 154],
#         [ 12,  55, 133],
#         ...,
#         [  8,  58, 155],
#         [ 30,  79, 172],
#         [ 59, 110, 201]],
#
#        [[113, 194, 255],
#         [  8,  77, 155],
#         [  5,  46, 125],
# ...

# %%
data.shape
# Out:
# (510, 390, 3)

# %%
# NUMBER OF COLUMNS

510*390*3

# 596700 values stored under 1 Image
# Out:
# 596700

# %%
# CONVERTING THE IMAGE INTO GREY SCALE(BLACK AND WHITE ---> 2D)

gs_pic = pic1.convert(mode='L')
gs_pic
# Out:
# <PIL.Image.Image image mode=L size=390x510>

# %%
gs_pic.size
# Out:
# (390, 510)

# %%
# CONVERT THE IMAGE INTO ARRAY
data_gs = asarray(gs_pic)
data_gs
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [142,  64,  61, ...,  62,  64,  92],
#        [162,  62,  51, ...,  54,  75, 105],
#        [177,  65,  43, ..., 105, 137, 159]], dtype=uint8)

# %%
data_gs.shape
# Out:
# (510, 390)
